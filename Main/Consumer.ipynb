# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col, udf
from pyspark.sql.types import StructType, StructField, FloatType
from joblib import load

spark = SparkSession.builder \
    .appName("HorseRaceConsumer") \
    .getOrCreate()

schema = StructType([
    StructField("jockey_score", FloatType(), True),
    StructField("horse_track_relative_score", FloatType(), True),
    StructField("horse_course_relative_score", FloatType(), True),
    StructField("horse_race_relative_score", FloatType(), True),
    StructField("distance_id", FloatType(), True),
    StructField("weight_carried", FloatType(), True),
    StructField("odds", FloatType(), True),
    StructField("position_at_finish", FloatType(), True)  # Target column
])

model = load("horsemodel_randomforest.pkl")
broadcast_model = spark.sparkContext.broadcast(model)

def predict(jockey_score, horse_track_relative_score, horse_course_relative_score,
            horse_race_relative_score, distance_id, weight_carried, odds):
    feature_list = [jockey_score, horse_track_relative_score, horse_course_relative_score,
                    horse_race_relative_score, distance_id, weight_carried, odds]
    return float(broadcast_model.value.predict([feature_list])[0])

predict_udf = udf(predict, FloatType())

kafka_topic = "data_analytics"
kafka_bootstrap_servers = "localhost:9092"

kafka_df = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", kafka_bootstrap_servers) \
    .option("subscribe", kafka_topic) \
    .load()

parsed_df = kafka_df.selectExpr("CAST(value AS STRING) AS value") \
    .select(from_json(col("value"), schema).alias("parsed_value")) \
    .select("parsed_value.*")  # Flatten the parsed JSON fields

predictions_df = parsed_df.withColumn(
    "prediction",
    predict_udf(
        col("jockey_score"),
        col("horse_track_relative_score"),
        col("horse_course_relative_score"),
        col("horse_race_relative_score"),
        col("distance_id"),
        col("weight_carried"),
        col("odds")
    )
)

total_predictions = spark.sparkContext.accumulator(0)
correct_predictions = spark.sparkContext.accumulator(0)
close_predictions = spark.sparkContext.accumulator(0)

def process_batch(batch_df, batch_id):
    global total_predictions, correct_predictions, close_predictions
    rows = batch_df.collect()

    for row in rows:
        actual = row["position_at_finish"]
        predicted = round(row["prediction"])

        print(f"Predicted: {predicted}, Actual: {actual}")

        total_predictions += 1
        if actual == predicted:
            correct_predictions += 1
        elif abs(actual - predicted) <= 2:
            close_predictions += 1

    if total_predictions.value > 0:
        correct_percentage = (correct_predictions.value / total_predictions.value) * 100
        close_percentage = (close_predictions.value / total_predictions.value) * 100
    else:
        correct_percentage = 0.0
        close_percentage = 0.0

    # Print percentages
    print(f"Correct Predictions: {correct_percentage:.2f}%")
    print(f"Close Predictions: {close_percentage:.2f}%")
    print("-" * 50)

# Use foreachBatch for real-time processing
query = predictions_df.writeStream \
    .foreachBatch(process_batch) \
    .outputMode("append") \
    .start()

query.awaitTermination()
# Out:
# Correct Predictions: 0.00%
# Close Predictions: 0.00%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 0.00%
# Close Predictions: 100.00%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 60.00%
# Close Predictions: 40.00%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 6, Actual: 9.0
# Correct Predictions: 42.86%
# Close Predictions: 42.86%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 7, Actual: 7.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 40.00%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 5, Actual: 3.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 33.33%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 5, Actual: 8.0
# Correct Predictions: 28.57%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 8, Actual: 6.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 25.00%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 27.78%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 6, Actual: 1.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 30.00%
# Close Predictions: 45.00%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 5, Actual: 8.0
# Correct Predictions: 27.27%
# Close Predictions: 45.45%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 25.00%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 4, Actual: 1.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 23.08%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 21.43%
# Close Predictions: 53.57%
# --------------------------------------------------
# Predicted: 9, Actual: 3.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 20.00%
# Close Predictions: 53.33%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 21.88%
# Close Predictions: 53.12%
# --------------------------------------------------
# Predicted: 6, Actual: 4.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 20.59%
# Close Predictions: 55.88%
# --------------------------------------------------
# Predicted: 7, Actual: 7.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 22.22%
# Close Predictions: 55.56%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 8, Actual: 6.0
# Correct Predictions: 21.05%
# Close Predictions: 57.89%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 10, Actual: 10.0
# Correct Predictions: 25.00%
# Close Predictions: 55.00%
# --------------------------------------------------
# Predicted: 9, Actual: 11.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 26.19%
# Close Predictions: 54.76%
# --------------------------------------------------
# Predicted: 9, Actual: 10.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 25.00%
# Close Predictions: 56.82%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 7, Actual: 7.0
# Correct Predictions: 28.26%
# Close Predictions: 54.35%
# --------------------------------------------------
# Predicted: 3, Actual: 2.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 29.17%
# Close Predictions: 54.17%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 30.00%
# Close Predictions: 52.00%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 30.77%
# Close Predictions: 51.92%
# --------------------------------------------------
# Predicted: 8, Actual: 10.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 31.48%
# Close Predictions: 51.85%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 32.14%
# Close Predictions: 51.79%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 6, Actual: 9.0
# Correct Predictions: 32.76%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 6, Actual: 2.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 31.67%
# Close Predictions: 50.00%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 30.65%
# Close Predictions: 51.61%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 31.25%
# Close Predictions: 51.56%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 30.30%
# Close Predictions: 53.03%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 30.88%
# Close Predictions: 52.94%
# --------------------------------------------------
# Predicted: 8, Actual: 11.0
# Predicted: 9, Actual: 6.0
# Correct Predictions: 30.00%
# Close Predictions: 51.43%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 29.17%
# Close Predictions: 52.78%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 4, Actual: 8.0
# Correct Predictions: 29.73%
# Close Predictions: 51.35%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 9, Actual: 6.0
# Correct Predictions: 28.95%
# Close Predictions: 51.32%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 29.49%
# Close Predictions: 51.28%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 28.75%
# Close Predictions: 52.50%
# --------------------------------------------------
# Predicted: 5, Actual: 9.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 28.05%
# Close Predictions: 52.44%
# --------------------------------------------------
# Predicted: 5, Actual: 2.0
# Predicted: 7, Actual: 9.0
# Correct Predictions: 27.38%
# Close Predictions: 52.38%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 4, Actual: 6.0
# Correct Predictions: 27.91%
# Close Predictions: 52.33%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 7, Actual: 5.0
# Correct Predictions: 27.27%
# Close Predictions: 53.41%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 27.78%
# Close Predictions: 53.33%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 7, Actual: 6.0
# Correct Predictions: 27.17%
# Close Predictions: 54.35%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 27.66%
# Close Predictions: 54.26%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 28.12%
# Close Predictions: 53.12%
# --------------------------------------------------
# Predicted: 2, Actual: 3.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 27.55%
# Close Predictions: 53.06%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 27.00%
# Close Predictions: 54.00%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 27.45%
# Close Predictions: 52.94%
# --------------------------------------------------
# Predicted: 7, Actual: 4.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 26.92%
# Close Predictions: 52.88%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 6, Actual: 4.0
# Correct Predictions: 27.36%
# Close Predictions: 52.83%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 9, Actual: 7.0
# Correct Predictions: 26.85%
# Close Predictions: 53.70%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 26.36%
# Close Predictions: 54.55%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 26.79%
# Close Predictions: 54.46%
# --------------------------------------------------
# Predicted: 7, Actual: 6.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 27.19%
# Close Predictions: 54.39%
# --------------------------------------------------
# Predicted: 4, Actual: 6.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 26.72%
# Close Predictions: 55.17%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 27.12%
# Close Predictions: 55.08%
# --------------------------------------------------
# Predicted: 9, Actual: 10.0
# Predicted: 8, Actual: 9.0
# Correct Predictions: 26.67%
# Close Predictions: 55.83%
# --------------------------------------------------
# Predicted: 2, Actual: 2.0
# Predicted: 5, Actual: 8.0
# Correct Predictions: 27.05%
# Close Predictions: 54.92%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 4, Actual: 6.0
# Correct Predictions: 27.42%
# Close Predictions: 54.84%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 26.98%
# Close Predictions: 54.76%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 26.56%
# Close Predictions: 55.47%
# --------------------------------------------------
# Predicted: 7, Actual: 7.0
# Predicted: 8, Actual: 6.0
# Correct Predictions: 26.92%
# Close Predictions: 55.38%
# --------------------------------------------------
# Predicted: 9, Actual: 7.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 26.52%
# Close Predictions: 56.06%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 26.87%
# Close Predictions: 55.97%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 9.0
# Correct Predictions: 26.47%
# Close Predictions: 55.88%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 26.81%
# Close Predictions: 55.80%
# --------------------------------------------------
# Predicted: 7, Actual: 7.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 27.14%
# Close Predictions: 55.71%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 27.46%
# Close Predictions: 55.63%
# --------------------------------------------------
# Predicted: 9, Actual: 10.0
# Predicted: 8, Actual: 4.0
# Correct Predictions: 27.08%
# Close Predictions: 55.56%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 7, Actual: 9.0
# Correct Predictions: 26.71%
# Close Predictions: 56.16%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 7, Actual: 7.0
# Correct Predictions: 27.03%
# Close Predictions: 56.08%
# --------------------------------------------------
# Predicted: 3, Actual: 2.0
# Predicted: 4, Actual: 9.0
# Correct Predictions: 26.67%
# Close Predictions: 56.00%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 26.32%
# Close Predictions: 55.92%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 26.62%
# Close Predictions: 55.84%
# --------------------------------------------------
# Predicted: 7, Actual: 8.0
# Predicted: 6, Actual: 3.0
# Correct Predictions: 26.28%
# Close Predictions: 55.77%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 26.58%
# Close Predictions: 55.70%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 7, Actual: 2.0
# Correct Predictions: 26.25%
# Close Predictions: 55.62%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 26.54%
# Close Predictions: 55.56%
# --------------------------------------------------
# Predicted: 6, Actual: 1.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 26.22%
# Close Predictions: 55.49%
# --------------------------------------------------
# Predicted: 9, Actual: 6.0
# Predicted: 2, Actual: 3.0
# Correct Predictions: 25.90%
# Close Predictions: 55.42%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 9, Actual: 10.0
# Correct Predictions: 25.60%
# Close Predictions: 55.95%
# --------------------------------------------------
# Predicted: 3, Actual: 1.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 25.88%
# Close Predictions: 55.88%
# --------------------------------------------------
# Predicted: 7, Actual: 6.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 25.58%
# Close Predictions: 56.40%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 25.86%
# Close Predictions: 56.32%
# --------------------------------------------------
# Predicted: 5, Actual: 9.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 25.57%
# Close Predictions: 56.25%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 25.84%
# Close Predictions: 56.18%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 8, Actual: 5.0
# Correct Predictions: 26.11%
# Close Predictions: 55.56%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 26.37%
# Close Predictions: 55.49%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 26.09%
# Close Predictions: 55.43%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 26.34%
# Close Predictions: 55.38%
# --------------------------------------------------
# Predicted: 7, Actual: 8.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 26.06%
# Close Predictions: 55.85%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 8, Actual: 11.0
# Correct Predictions: 25.79%
# Close Predictions: 55.79%
# --------------------------------------------------
# Predicted: 4, Actual: 6.0
# Predicted: 7, Actual: 7.0
# Correct Predictions: 26.04%
# Close Predictions: 55.73%
# --------------------------------------------------
# Predicted: 3, Actual: 6.0
# Predicted: 4, Actual: 6.0
# Correct Predictions: 25.77%
# Close Predictions: 55.67%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 6, Actual: 2.0
# Correct Predictions: 25.51%
# Close Predictions: 55.10%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 25.76%
# Close Predictions: 55.05%
# --------------------------------------------------
# Predicted: 9, Actual: 11.0
# Predicted: 4, Actual: 6.0
# Correct Predictions: 25.50%
# Close Predictions: 55.50%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 25.25%
# Close Predictions: 55.94%
# --------------------------------------------------
# Predicted: 9, Actual: 10.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 25.49%
# Close Predictions: 55.88%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 25.73%
# Close Predictions: 55.83%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 9, Actual: 7.0
# Correct Predictions: 25.48%
# Close Predictions: 56.25%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 25.24%
# Close Predictions: 56.19%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 25.00%
# Close Predictions: 56.60%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 24.77%
# Close Predictions: 57.01%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 4.0
# Correct Predictions: 24.54%
# Close Predictions: 57.41%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 24.77%
# Close Predictions: 57.34%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 24.55%
# Close Predictions: 57.73%
# --------------------------------------------------
# Predicted: 10, Actual: 11.0
# Predicted: 8, Actual: 6.0
# Correct Predictions: 24.32%
# Close Predictions: 58.11%
# --------------------------------------------------
# Predicted: 6, Actual: 4.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 24.11%
# Close Predictions: 58.48%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 6, Actual: 10.0
# Correct Predictions: 24.34%
# Close Predictions: 57.96%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 24.12%
# Close Predictions: 58.33%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 23.91%
# Close Predictions: 58.70%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 9, Actual: 10.0
# Correct Predictions: 23.71%
# Close Predictions: 59.05%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 23.50%
# Close Predictions: 59.40%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 23.31%
# Close Predictions: 59.75%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 23.53%
# Close Predictions: 59.66%
# --------------------------------------------------
# Predicted: 4, Actual: 6.0
# Predicted: 4, Actual: 6.0
# Correct Predictions: 23.33%
# Close Predictions: 60.00%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 23.14%
# Close Predictions: 60.33%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 22.95%
# Close Predictions: 60.66%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.76%
# Close Predictions: 60.98%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 8, Actual: 12.0
# Correct Predictions: 22.58%
# Close Predictions: 60.89%
# --------------------------------------------------
# Predicted: 7, Actual: 8.0
# Predicted: 6, Actual: 9.0
# Correct Predictions: 22.40%
# Close Predictions: 60.80%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.02%
# Close Predictions: 60.32%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 4, Actual: 6.0
# Correct Predictions: 22.83%
# Close Predictions: 60.63%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 23.05%
# Close Predictions: 60.55%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 7, Actual: 10.0
# Correct Predictions: 22.87%
# Close Predictions: 60.47%
# --------------------------------------------------
# Predicted: 5, Actual: 3.0
# Predicted: 9, Actual: 11.0
# Correct Predictions: 22.69%
# Close Predictions: 60.77%
# --------------------------------------------------
# Predicted: 8, Actual: 10.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 22.52%
# Close Predictions: 61.07%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 22.73%
# Close Predictions: 60.98%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.56%
# Close Predictions: 61.28%
# --------------------------------------------------
# Predicted: 2, Actual: 2.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 22.76%
# Close Predictions: 61.19%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 22.59%
# Close Predictions: 61.48%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 3, Actual: 4.0
# Correct Predictions: 22.43%
# Close Predictions: 61.40%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 22.26%
# Close Predictions: 61.31%
# --------------------------------------------------
# Predicted: 6, Actual: 2.0
# Predicted: 6, Actual: 10.0
# Correct Predictions: 22.10%
# Close Predictions: 60.87%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 21.94%
# Close Predictions: 61.15%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 22.14%
# Close Predictions: 61.07%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 2, Actual: 2.0
# Correct Predictions: 22.34%
# Close Predictions: 60.99%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 22.18%
# Close Predictions: 61.27%
# --------------------------------------------------
# Predicted: 3, Actual: 3.0
# Predicted: 5, Actual: 8.0
# Correct Predictions: 22.38%
# Close Predictions: 60.84%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 3.0
# Correct Predictions: 22.22%
# Close Predictions: 60.76%
# --------------------------------------------------
# Predicted: 5, Actual: 2.0
# Predicted: 7, Actual: 5.0
# Correct Predictions: 22.07%
# Close Predictions: 60.69%
# --------------------------------------------------
# Predicted: 10, Actual: 11.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 21.92%
# Close Predictions: 60.96%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 6, Actual: 3.0
# Correct Predictions: 22.11%
# Close Predictions: 60.54%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 22.30%
# Close Predictions: 60.47%
# --------------------------------------------------
# Predicted: 5, Actual: 2.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.15%
# Close Predictions: 60.40%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 22.33%
# Close Predictions: 60.33%
# --------------------------------------------------
# Predicted: 5, Actual: 8.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 22.19%
# Close Predictions: 60.26%
# --------------------------------------------------
# Predicted: 7, Actual: 7.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 22.37%
# Close Predictions: 60.20%
# --------------------------------------------------
# Predicted: 3, Actual: 2.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 22.22%
# Close Predictions: 60.13%
# --------------------------------------------------
# Predicted: 7, Actual: 6.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 22.08%
# Close Predictions: 60.39%
# --------------------------------------------------
# Predicted: 2, Actual: 2.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.26%
# Close Predictions: 60.32%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 22.12%
# Close Predictions: 60.58%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 22.29%
# Close Predictions: 60.51%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 22.15%
# Close Predictions: 60.76%
# --------------------------------------------------
# Predicted: 2, Actual: 3.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 22.33%
# Close Predictions: 60.69%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 22.50%
# Close Predictions: 60.31%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 7, Actual: 5.0
# Correct Predictions: 22.36%
# Close Predictions: 60.56%
# --------------------------------------------------
# Predicted: 3, Actual: 3.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 22.84%
# Close Predictions: 60.19%
# --------------------------------------------------
# Predicted: 5, Actual: 1.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.01%
# Close Predictions: 59.82%
# --------------------------------------------------
# Predicted: 5, Actual: 2.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.87%
# Close Predictions: 59.76%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 3, Actual: 4.0
# Correct Predictions: 22.73%
# Close Predictions: 60.00%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.19%
# Close Predictions: 59.64%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 23.05%
# Close Predictions: 59.88%
# --------------------------------------------------
# Predicted: 3, Actual: 3.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 23.21%
# Close Predictions: 59.52%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 23.37%
# Close Predictions: 59.47%
# --------------------------------------------------
# Predicted: 9, Actual: 11.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.53%
# Close Predictions: 59.41%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 23.68%
# Close Predictions: 59.36%
# --------------------------------------------------
# Predicted: 3, Actual: 5.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.84%
# Close Predictions: 59.30%
# --------------------------------------------------
# Predicted: 4, Actual: 7.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 23.70%
# Close Predictions: 59.25%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 8, Actual: 7.0
# Correct Predictions: 23.85%
# Close Predictions: 59.20%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 24.29%
# Close Predictions: 58.86%
# --------------------------------------------------
# Predicted: 4, Actual: 9.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 24.15%
# Close Predictions: 58.52%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 24.29%
# Close Predictions: 58.47%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 24.16%
# Close Predictions: 58.71%
# --------------------------------------------------
# Predicted: 4, Actual: 8.0
# Predicted: 7, Actual: 10.0
# Correct Predictions: 24.02%
# Close Predictions: 58.38%
# --------------------------------------------------
# Predicted: 6, Actual: 3.0
# Predicted: 5, Actual: 1.0
# Correct Predictions: 23.89%
# Close Predictions: 58.06%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 23.76%
# Close Predictions: 58.29%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 23.63%
# Close Predictions: 58.52%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 7, Actual: 9.0
# Correct Predictions: 23.77%
# Close Predictions: 58.47%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 7, Actual: 7.0
# Correct Predictions: 23.91%
# Close Predictions: 58.42%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 5, Actual: 10.0
# Correct Predictions: 23.78%
# Close Predictions: 58.38%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 23.66%
# Close Predictions: 58.33%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 23.80%
# Close Predictions: 58.29%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 7, Actual: 7.0
# Correct Predictions: 23.94%
# Close Predictions: 58.24%
# --------------------------------------------------
# Predicted: 5, Actual: 1.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 23.81%
# Close Predictions: 58.20%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 23.95%
# Close Predictions: 58.16%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 23.82%
# Close Predictions: 58.12%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 8, Actual: 5.0
# Correct Predictions: 23.70%
# Close Predictions: 57.81%
# --------------------------------------------------
# Predicted: 8, Actual: 10.0
# Predicted: 5, Actual: 9.0
# Correct Predictions: 23.58%
# Close Predictions: 57.77%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 3, Actual: 3.0
# Correct Predictions: 23.71%
# Close Predictions: 57.73%
# --------------------------------------------------
# Predicted: 7, Actual: 12.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 23.59%
# Close Predictions: 57.69%
# --------------------------------------------------
# Predicted: 8, Actual: 10.0
# Predicted: 9, Actual: 10.0
# Correct Predictions: 23.47%
# Close Predictions: 57.91%
# --------------------------------------------------
# Predicted: 6, Actual: 11.0
# Predicted: 5, Actual: 9.0
# Correct Predictions: 23.35%
# Close Predictions: 57.61%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 23.23%
# Close Predictions: 57.83%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 23.37%
# Close Predictions: 57.79%
# --------------------------------------------------
# Predicted: 4, Actual: 6.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 23.25%
# Close Predictions: 57.75%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 23.38%
# Close Predictions: 57.71%
# --------------------------------------------------
# Predicted: 2, Actual: 2.0
# Predicted: 7, Actual: 8.0
# Correct Predictions: 23.51%
# Close Predictions: 57.67%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 9, Actual: 4.0
# Correct Predictions: 23.40%
# Close Predictions: 57.39%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 7, Actual: 10.0
# Correct Predictions: 23.28%
# Close Predictions: 57.35%
# --------------------------------------------------
# Predicted: 9, Actual: 11.0
# Predicted: 9, Actual: 11.0
# Correct Predictions: 23.17%
# Close Predictions: 57.56%
# --------------------------------------------------
# Predicted: 5, Actual: 8.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 23.30%
# Close Predictions: 57.28%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 5, Actual: 7.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 23.13%
# Close Predictions: 57.59%
# --------------------------------------------------
# Predicted: 6, Actual: 3.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.26%
# Close Predictions: 57.31%
# --------------------------------------------------
# Predicted: 8, Actual: 12.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 23.39%
# Close Predictions: 57.04%
# --------------------------------------------------
# Predicted: 8, Actual: 11.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 23.52%
# Close Predictions: 56.77%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 23.40%
# Close Predictions: 56.97%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 23.76%
# Close Predictions: 56.71%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 6, Actual: 3.0
# Correct Predictions: 23.65%
# Close Predictions: 56.67%
# --------------------------------------------------
# Predicted: 3, Actual: 1.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 23.54%
# Close Predictions: 56.88%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 23.43%
# Close Predictions: 57.08%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 23.33%
# Close Predictions: 57.27%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 23.22%
# Close Predictions: 57.47%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 4, Actual: 3.0
# Correct Predictions: 23.11%
# Close Predictions: 57.67%
# --------------------------------------------------
# Predicted: 6, Actual: 2.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 23.01%
# Close Predictions: 57.63%
# --------------------------------------------------
# Predicted: 8, Actual: 5.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 23.13%
# Close Predictions: 57.37%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 23.02%
# Close Predictions: 57.34%
# --------------------------------------------------
# Predicted: 5, Actual: 2.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.15%
# Close Predictions: 57.08%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 8, Actual: 7.0
# Correct Predictions: 23.04%
# Close Predictions: 57.27%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 2, Actual: 4.0
# Correct Predictions: 22.94%
# Close Predictions: 57.46%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 1, Actual: 1.0
# Correct Predictions: 23.28%
# Close Predictions: 57.21%
# --------------------------------------------------
# Predicted: 3, Actual: 4.0
# Predicted: 9, Actual: 11.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.35%
# Close Predictions: 57.27%
# --------------------------------------------------
# Predicted: 8, Actual: 10.0
# Predicted: 9, Actual: 11.0
# Correct Predictions: 23.25%
# Close Predictions: 57.46%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 23.36%
# Close Predictions: 57.42%
# --------------------------------------------------
# Predicted: 4, Actual: 3.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 23.26%
# Close Predictions: 57.61%
# --------------------------------------------------
# Predicted: 7, Actual: 8.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 23.16%
# Close Predictions: 57.79%
# --------------------------------------------------
# Predicted: 3, Actual: 6.0
# Predicted: 5, Actual: 9.0
# Correct Predictions: 23.06%
# Close Predictions: 57.54%
# --------------------------------------------------
# Predicted: 3, Actual: 1.0
# Predicted: 5, Actual: 1.0
# Correct Predictions: 22.96%
# Close Predictions: 57.51%
# --------------------------------------------------
# Predicted: 5, Actual: 1.0
# Predicted: 6, Actual: 6.0
# Predicted: 6, Actual: 3.0
# Correct Predictions: 23.03%
# Close Predictions: 57.14%
# --------------------------------------------------
# Predicted: 5, Actual: 4.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 22.93%
# Close Predictions: 57.32%
# --------------------------------------------------
# Predicted: 6, Actual: 12.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.04%
# Close Predictions: 57.08%
# --------------------------------------------------
# Predicted: 5, Actual: 1.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.95%
# Close Predictions: 57.05%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 22.85%
# Close Predictions: 57.23%
# --------------------------------------------------
# Predicted: 3, Actual: 2.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.76%
# Close Predictions: 57.41%
# --------------------------------------------------
# Predicted: 6, Actual: 4.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.66%
# Close Predictions: 57.59%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 22.77%
# Close Predictions: 57.56%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 6.0
# Predicted: 6, Actual: 4.0
# Correct Predictions: 22.84%
# Close Predictions: 57.61%
# --------------------------------------------------
# Predicted: 4, Actual: 7.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.75%
# Close Predictions: 57.58%
# --------------------------------------------------
# Predicted: 4, Actual: 6.0
# Predicted: 6, Actual: 3.0
# Correct Predictions: 22.65%
# Close Predictions: 57.55%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 22.56%
# Close Predictions: 57.52%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 2, Actual: 2.0
# Correct Predictions: 22.67%
# Close Predictions: 57.49%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.78%
# Close Predictions: 57.46%
# --------------------------------------------------
# Predicted: 5, Actual: 8.0
# Predicted: 6, Actual: 4.0
# Correct Predictions: 22.69%
# Close Predictions: 57.43%
# --------------------------------------------------
# Predicted: 6, Actual: 10.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 22.60%
# Close Predictions: 57.40%
# --------------------------------------------------
# Predicted: 2, Actual: 1.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 22.51%
# Close Predictions: 57.37%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.42%
# Close Predictions: 57.54%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 3, Actual: 4.0
# Correct Predictions: 22.33%
# Close Predictions: 57.71%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 22.44%
# Close Predictions: 57.68%
# --------------------------------------------------
# Predicted: 8, Actual: 4.0
# Predicted: 1, Actual: 1.0
# Correct Predictions: 22.55%
# Close Predictions: 57.45%
# --------------------------------------------------
# Predicted: 8, Actual: 6.0
# Predicted: 8, Actual: 6.0
# Correct Predictions: 22.46%
# Close Predictions: 57.62%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 22.57%
# Close Predictions: 57.59%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 8, Actual: 8.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 22.63%
# Close Predictions: 57.45%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 4, Actual: 2.0
# Correct Predictions: 22.74%
# Close Predictions: 57.42%
# --------------------------------------------------
# Predicted: 6, Actual: 3.0
# Predicted: 9, Actual: 7.0
# Correct Predictions: 22.65%
# Close Predictions: 57.39%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 22.75%
# Close Predictions: 57.17%
# --------------------------------------------------
# Predicted: 8, Actual: 2.0
# Predicted: 6, Actual: 5.0
# Correct Predictions: 22.67%
# Close Predictions: 57.14%
# --------------------------------------------------
# Predicted: 9, Actual: 11.0
# Predicted: 8, Actual: 6.0
# Correct Predictions: 22.58%
# Close Predictions: 57.31%
# --------------------------------------------------
# Predicted: 3, Actual: 1.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.50%
# Close Predictions: 57.47%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 22.60%
# Close Predictions: 57.44%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 22.70%
# Close Predictions: 57.41%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 22.80%
# Close Predictions: 57.20%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 8, Actual: 8.0
# Correct Predictions: 23.09%
# Close Predictions: 56.98%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 23.19%
# Close Predictions: 56.96%
# --------------------------------------------------
# Predicted: 7, Actual: 7.0
# Predicted: 10, Actual: 9.0
# Correct Predictions: 23.29%
# Close Predictions: 56.93%
# --------------------------------------------------
# Predicted: 6, Actual: 8.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 23.39%
# Close Predictions: 56.91%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 2, Actual: 1.0
# Correct Predictions: 23.30%
# Close Predictions: 57.06%
# --------------------------------------------------
# Predicted: 7, Actual: 10.0
# Predicted: 6, Actual: 7.0
# Correct Predictions: 23.22%
# Close Predictions: 57.04%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 23.13%
# Close Predictions: 57.19%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 23.23%
# Close Predictions: 57.17%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 2, Actual: 3.0
# Correct Predictions: 23.15%
# Close Predictions: 57.32%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 9, Actual: 10.0
# Correct Predictions: 23.24%
# Close Predictions: 57.30%
# --------------------------------------------------
# Predicted: 6, Actual: 7.0
# Predicted: 6, Actual: 2.0
# Correct Predictions: 23.16%
# Close Predictions: 57.27%
# --------------------------------------------------
# Predicted: 6, Actual: 9.0
# Predicted: 9, Actual: 10.0
# Correct Predictions: 23.08%
# Close Predictions: 57.25%
# --------------------------------------------------
# Predicted: 7, Actual: 6.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 22.99%
# Close Predictions: 57.22%
# --------------------------------------------------
# Predicted: 9, Actual: 12.0
# Predicted: 8, Actual: 9.0
# Predicted: 10, Actual: 12.0
# Correct Predictions: 22.87%
# Close Predictions: 57.27%
# --------------------------------------------------
# Predicted: 3, Actual: 1.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 22.79%
# Close Predictions: 57.42%
# --------------------------------------------------
# Predicted: 8, Actual: 10.0
# Predicted: 10, Actual: 12.0
# Predicted: 9, Actual: 11.0
# Correct Predictions: 22.67%
# Close Predictions: 57.64%
# --------------------------------------------------
# Predicted: 8, Actual: 7.0
# Predicted: 8, Actual: 5.0
# Correct Predictions: 22.59%
# Close Predictions: 57.62%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 10, Actual: 8.0
# Predicted: 8, Actual: 10.0
# Correct Predictions: 22.47%
# Close Predictions: 57.84%
# --------------------------------------------------
# Predicted: 3, Actual: 3.0
# Predicted: 8, Actual: 10.0
# Correct Predictions: 22.57%
# Close Predictions: 57.81%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 6, Actual: 4.0
# Predicted: 6, Actual: 8.0
# Correct Predictions: 22.45%
# Close Predictions: 58.03%
# --------------------------------------------------
# Predicted: 9, Actual: 12.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.38%
# Close Predictions: 58.00%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 4, Actual: 1.0
# Correct Predictions: 22.30%
# Close Predictions: 57.98%
# --------------------------------------------------
# Predicted: 4, Actual: 9.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 22.39%
# Close Predictions: 57.78%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 8, Actual: 10.0
# Predicted: 5, Actual: 6.0
# Correct Predictions: 22.28%
# Close Predictions: 57.99%
# --------------------------------------------------
# Predicted: 6, Actual: 5.0
# Predicted: 3, Actual: 1.0
# Correct Predictions: 22.20%
# Close Predictions: 58.14%
# --------------------------------------------------
# Predicted: 9, Actual: 12.0
# Predicted: 5, Actual: 4.0
# Correct Predictions: 22.13%
# Close Predictions: 58.11%
# --------------------------------------------------
# Predicted: 7, Actual: 6.0
# Predicted: 4, Actual: 7.0
# Correct Predictions: 22.05%
# Close Predictions: 58.08%
# --------------------------------------------------
# Predicted: 4, Actual: 4.0
# Predicted: 9, Actual: 11.0
# Correct Predictions: 22.15%
# Close Predictions: 58.05%
# --------------------------------------------------
# Predicted: 4, Actual: 1.0
# Predicted: 7, Actual: 4.0
# Correct Predictions: 22.07%
# Close Predictions: 57.86%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 9, Actual: 11.0
# Correct Predictions: 22.00%
# Close Predictions: 58.00%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 9, Actual: 8.0
# Correct Predictions: 22.09%
# Close Predictions: 57.97%
# --------------------------------------------------
# Predicted: 9, Actual: 10.0
# Predicted: 4, Actual: 4.0
# Correct Predictions: 22.19%
# Close Predictions: 57.95%
# --------------------------------------------------
# Predicted: 5, Actual: 5.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 22.28%
# Close Predictions: 57.76%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 22.37%
# Close Predictions: 57.73%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 22.62%
# Close Predictions: 57.54%
# --------------------------------------------------
# Predicted: 9, Actual: 9.0
# Predicted: 4, Actual: 5.0
# Correct Predictions: 22.71%
# Close Predictions: 57.52%
# --------------------------------------------------
# Predicted: 10, Actual: 12.0
# Predicted: 8, Actual: 5.0
# Correct Predictions: 22.64%
# Close Predictions: 57.49%
# --------------------------------------------------
# Predicted: 5, Actual: 1.0
# Predicted: 5, Actual: 1.0
# Correct Predictions: 22.56%
# Close Predictions: 57.31%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 5, Actual: 2.0
# Correct Predictions: 22.65%
# Close Predictions: 57.12%
# --------------------------------------------------
# Predicted: 5, Actual: 6.0
# Predicted: 7, Actual: 8.0
# Correct Predictions: 22.58%
# Close Predictions: 57.26%
# --------------------------------------------------
# Predicted: 6, Actual: 6.0
# Predicted: 8, Actual: 9.0
# Correct Predictions: 22.67%
# Close Predictions: 57.23%
# --------------------------------------------------
# Predicted: 9, Actual: 8.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 22.76%
# Close Predictions: 57.21%
# --------------------------------------------------
# Predicted: 9, Actual: 7.0
# Predicted: 5, Actual: 7.0
# Correct Predictions: 22.68%
# Close Predictions: 57.35%
# --------------------------------------------------
# Predicted: 2, Actual: 2.0
# Predicted: 9, Actual: 9.0
# Correct Predictions: 22.93%
# Close Predictions: 57.17%
# --------------------------------------------------
# Predicted: 9, Actual: 5.0
# Predicted: 9, Actual: 12.0
# Correct Predictions: 22.86%
# Close Predictions: 56.98%
# --------------------------------------------------
# Predicted: 7, Actual: 10.0
# Predicted: 8, Actual: 6.0
# Correct Predictions: 22.78%
# Close Predictions: 56.96%
# --------------------------------------------------
# Predicted: 5, Actual: 7.0
# Predicted: 6, Actual: 6.0
# Correct Predictions: 22.87%
# Close Predictions: 56.94%
# --------------------------------------------------
# Predicted: 7, Actual: 9.0
# Predicted: 1, Actual: 1.0
# Correct Predictions: 22.96%
# Close Predictions: 56.92%
# --------------------------------------------------
# Predicted: 4, Actual: 2.0
# Predicted: 5, Actual: 3.0
# Correct Predictions: 22.88%
# Close Predictions: 57.05%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 8, Actual: 12.0
# Correct Predictions: 22.97%
# Close Predictions: 56.88%
# --------------------------------------------------
# Predicted: 4, Actual: 5.0
# Predicted: 8, Actual: 7.0
# Correct Predictions: 22.90%
# Close Predictions: 57.01%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 9, Actual: 10.0
# Correct Predictions: 22.83%
# Close Predictions: 57.14%
# --------------------------------------------------
# Predicted: 5, Actual: 11.0
# Predicted: 5, Actual: 3.0
# Predicted: 2, Actual: 2.0
# Correct Predictions: 22.87%
# Close Predictions: 57.03%
# --------------------------------------------------
# Predicted: 8, Actual: 9.0
# Predicted: 9, Actual: 6.0
# Correct Predictions: 22.80%
# Close Predictions: 57.01%
# --------------------------------------------------
# Predicted: 6, Actual: 2.0
# Predicted: 7, Actual: 3.0
# Correct Predictions: 22.73%
# Close Predictions: 56.84%
# --------------------------------------------------
# Predicted: 8, Actual: 8.0
# Predicted: 5, Actual: 5.0
# Correct Predictions: 22.97%
# Close Predictions: 56.66%
# --------------------------------------------------

# %%
# IT WAS COMPLETE, I MANUALLY STOPPED IT.
